# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-8fb7d5e4-e94e-4634-bbe2-9bf0bd403158" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fb7d5e4-e94e-4634-bbe2-9bf0bd403158">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df.head()
# Out:
#                            Job Title               Salary Estimate  Rating  \
# 0              Senior Data Scientist  $111K-$181K (Glassdoor est.)     3.5
# 1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)     4.5
# 2               Data Science Manager  $111K-$181K (Glassdoor est.)    -1.0
# 3                       Data Analyst  $111K-$181K (Glassdoor est.)     3.4
# 4             Director, Data Science  $111K-$181K (Glassdoor est.)     3.4
#
#                       Company Name       Location                    Size  \
# 0                      Hopper\n3.5   New York, NY   501 to 1000 employees
# 1                     Noom US\n4.5   New York, NY  1001 to 5000 employees
# 2                         Decode_M   New York, NY       1 to 50 employees
# 3            Sapphire Digital\n3.4  Lyndhurst, NJ    201 to 500 employees
# 4  United Entertainment Group\n3.4   New York, NY     51 to 200 employees
#
#   Founded  Type of ownership                   Industry  \
# ...

# %%
df.tail()
# Out:
#                                      Job Title               Salary Estimate  \
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
#       Rating                          Company Name       Location  \
# 5887     3.6                      Hose Master\n3.6     Euclid, OH
# 5888     4.9                 Bluetree Network\n4.9    Madison, WI
# 5889     4.0  Kimberly-Clark Corporation, LLC\n4.0     Neenah, WI
# 5890     4.0            AE Business Solutions\n4.0    Madison, WI
# 5891     3.7                           Epitec\n3.7  Wisconsin, WI
#
#                         Size Founded  Type of ownership  \
# ...

# %%
df ['Salary Estimate END']= df['Salary Estimate'].str.replace('(Glassdoor est.)', '')
# Out:
# <ipython-input-9-49ddc7c43bfb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df ['Salary Estimate END']= df['Salary Estimate'].str.replace('(Glassdoor est.)', '')

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df['Salary Estimate END'] = df['Salary Estimate END'].str.replace('K','000')

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
def Salary_Estimate(a):
  a = a.replace('-','--')
  return a

# %%
Salary_Estimate('Camellia is a good girl - ')
# Out:
# 'Camellia is a good girl -- '

# %%
df
# Out:
#                                      Job Title               Salary Estimate  \
# 0                        Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1            Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2                         Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                                 Data Analyst  $111K-$181K (Glassdoor est.)
# 4                       Director, Data Science  $111K-$181K (Glassdoor est.)
# ...                                        ...                           ...
# 5887       Manufacturing Data Analyst Engineer  $42K - $76K (Glassdoor est.)
# 5888                            Data Scientist                            -1
# 5889  Supply Chain Consultant - Data Scientist                            -1
# 5890                     Data Science Engineer                            -1
# 5891      Data Scientist/ Full Stack Developer            $65 - $72 Per Hour
#
# ...

# %%
df2 = df[df['Salary Estimate END'] != '-1']

# %%
df2
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
# 5891               Data Scientist/ Full Stack Developer
#
#                     Salary Estimate  Rating  \
# 0      $111K-$181K (Glassdoor est.)     3.5
# 1      $111K-$181K (Glassdoor est.)     4.5
# 2      $111K-$181K (Glassdoor est.)    -1.0
# 3      $111K-$181K (Glassdoor est.)     3.4
# 4      $111K-$181K (Glassdoor est.)     3.4
# ...

# %%
df3 = df2[~df2['Salary Estimate END'].str.contains('Per Hour')]

# %%
df3
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 5881                              Information Scientist
# 5882              Supervisory Research Health Scientist
# 5883                  Senior SAS Programmer (Scientist)
# 5886  Senior Data Analyst - Product Analytics (open ...
# 5887                Manufacturing Data Analyst Engineer
#
#                     Salary Estimate  Rating  \
# 0      $111K-$181K (Glassdoor est.)     3.5
# 1      $111K-$181K (Glassdoor est.)     4.5
# 2      $111K-$181K (Glassdoor est.)    -1.0
# 3      $111K-$181K (Glassdoor est.)     3.4
# 4      $111K-$181K (Glassdoor est.)     3.4
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5500 entries, 0 to 5887
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Job Title            5500 non-null   object
#  1   Salary Estimate      5500 non-null   object
#  2   Rating               5500 non-null   float64
#  3   Company Name         5500 non-null   object
#  4   Location             5500 non-null   object
#  5   Size                 5500 non-null   object
#  6   Founded              5500 non-null   object
#  7   Type of ownership    5500 non-null   object
#  8   Industry             5500 non-null   object
#  9   Sector               5500 non-null   object
#  10  Revenue              5500 non-null   object
#  11  Salary Estimate END  5500 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 558.6+ KB

# %%
df3[df3['Salary Estimate END'].split()[1]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-adb821a40d40> in <cell line: 1>()
# ----> 1 df3[df3['Salary Estimate END'].split()[1]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'
